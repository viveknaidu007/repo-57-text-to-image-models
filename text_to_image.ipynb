# %%
import requests

# %%
api_key = "SG_046e99fc3dd1a867"  #dont use my apikey key

url = "https://api.segmind.com/v1/sd1.5-realisticvision"

# %%
# below is prompt 
data = {
  "prompt": "((selfie)) photo of an american girl and guy, smiling, (yosemite:1.3), mountains, wearing a backpack, red top, hiking jacket, rocks, river, wood, analog style (look at viewer:1.2) (skin texture), close up, cinematic light, ((night sky:1.2)), (milkiway:1.4), sidelighting, Fujiflim XT3, DSLR, 50mm, (long windblown hair)",
  "negative_prompt": "\"(deformed, distorted, disfigured:1.3), poorly drawn, bad anatomy, wrong anatomy, extra limb, missing limb, floating limbs, (mutated hands and fingers:1.4), disconnected limbs, mutation, mutated, ugly, disgusting, blurry, amputation, render, 3d, 2d, sketch, painting, digital art, drawing, disfigured, ((nsfw)), ((breasts))",
  "scheduler": "dpmpp_2m",
  "num_inference_steps": 25,
  "guidance_scale": 6,
  "samples": 1,
  "seed": 4082622942,
  "img_width": 512,
  "img_height": 768,
  "base64": False
}

response = requests.post(url, json=data, headers={'x-api-key': api_key})
print(response)

#here we got response  = 200 ,it means it was sucesfull image generated according to docmentation

'''
200 - OKImage Generated
401 - UnauthorizedUser authentication failed
404 - Not FoundThe requested URL does not exist
405 - Method Not AllowedThe requested HTTP method is not allowed
406 - Not AcceptableNot enough credits
500 - Server ErrorServer had some issue with processing

'''
# Out:
# <Response [200]>

# %%
'''from PIL import Image
from io import BytesIO

# reponse we got
image_data = response.content

# opening image using PIL
image = Image.open(BytesIO(image_data))

# display the image
image.show()
#for displayin image in another tab
'''

# %%
from IPython.display import display

# we have content in our response
image_data = response.content

# image using PIL #python imaging library 
image = Image.open(BytesIO(image_data))

# display the image
display(image)
#to display image in our output
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x768>

# %%
#lets change the prompt

# %%
# lets go with panda

data = {
  "prompt": "((kung fu panda)) playing with food",
  "negative_prompt": "\"(deformed, distorted, disfigured:1.3), poorly drawn, bad anatomy, wrong anatomy, extra limb, missing limb, floating limbs, (mutated hands and fingers:1.4), disconnected limbs, mutation, mutated, ugly, disgusting, blurry, amputation, render, 3d, 2d, sketch, painting, digital art, drawing, disfigured, ((nsfw)), ((breasts))",
  "scheduler": "dpmpp_2m",
  "num_inference_steps": 25,
  "guidance_scale": 6,
  "samples": 1,
  "seed": 4082622942,
  "img_width": 512,
  "img_height": 768,
  "base64": False
}
response = requests.post(url, json=data, headers={'x-api-key': api_key})
print(response)
# Out:
# <Response [200]>

# %%
from IPython.display import display

# reponse object we received from the API
image_data = response.content

# image using PIL
image = Image.open(BytesIO(image_data))

# display
display(image)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x768>

# %%
#lets go with fashing design

data = {
  "prompt": "((fashion design)) new design , girl wearing , very new model , good design , ramp walk",
  "negative_prompt": "\"(deformed, distorted, disfigured:1.3), poorly drawn, bad anatomy, wrong anatomy, extra limb, missing limb, floating limbs, (mutated hands and fingers:1.4), disconnected limbs, mutation, mutated, ugly, disgusting, blurry, amputation, render, 3d, 2d, sketch, painting, digital art, drawing, disfigured, ((nsfw)), ((breasts))",
  "scheduler": "dpmpp_2m",
  "num_inference_steps": 25,
  "guidance_scale": 6,
  "samples": 1,
  "seed": 4082622942,
  "img_width": 512,
  "img_height": 768,
  "base64": False
}
response = requests.post(url, json=data, headers={'x-api-key': api_key})
print(response)
# Out:
# <Response [200]>

# %%
from IPython.display import display

# response object we received from the API
image_data = response.content

#opening image using PIL
image = Image.open(BytesIO(image_data))

# display
display(image)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x768>

# %%
#gor another prompt

data = {
  "prompt": "((fashion design)) new design , saree , latest model , girl wearing , good design , ramp walk , with people clicking images , red saree ",
  "negative_prompt": "\"(deformed, distorted, disfigured:1.3), poorly drawn, bad anatomy, wrong anatomy, extra limb, missing limb, floating limbs, (mutated hands and fingers:1.4), disconnected limbs, mutation, mutated, ugly, disgusting, blurry, amputation, render, 3d, 2d, sketch, painting, digital art, drawing, disfigured, ((nsfw)), ((breasts))",
  "scheduler": "dpmpp_2m",
  "num_inference_steps": 25,
  "guidance_scale": 6,
  "samples": 1,
  "seed": 4082622942,
  "img_width": 512,
  "img_height": 768,
  "base64": False
}
response = requests.post(url, json=data, headers={'x-api-key': api_key})
print(response)
# Out:
# <Response [200]>

# %%
from IPython.display import display

image_data = response.content

image = Image.open(BytesIO(image_data))

display(image)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x768>
